# %% [markdown]
# ## Plotting

# %% [markdown]
# Wir können unsere Daten darstellen
#
# https://matplotlib.org/stable/api/pyplot_summary.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data/PopFixed.csv", delimiter=",", thousands=",", decimal=".", index_col="Country (or dependency)")
df.drop(columns=["#"], inplace=True)

# %%
df.plot()  # Pandas hat eine direkte Integration mit matplotlib
# Out:
# <Axes: xlabel='Country (or dependency)'>

# %%
df["Population(2020)"].plot()
# Out:
# <Axes: xlabel='Country (or dependency)'>

# %% [markdown]
# ## Zwei Modi
#
# Globaler Modus und Objektorientierter Modus

# %%
plt.figure(figsize=(12, 6))
plt.xlabel("X")
plt.ylabel("Y")
plt.plot(df["Population(2020)"])  # Global

# %% [markdown]
# ## Objektorientierter Modus

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

# Hier in axes ist ein 2x2 Array enthalten

axes[0, 0].plot(x, x*x)
axes[0, 1].plot(x, -x*x)
axes[1, 0].plot(x, x*-x)
axes[1, 1].plot(x, -x*-x)

axes[0, 0].set_title("0, 0")
axes[0, 1].set_title("0, 1")
axes[1, 0].set_title("1, 0")
axes[1, 1].set_title("1, 1")
# Out:
# Text(0.5, 1.0, '1, 1')

# %% [markdown]
# ## Piechart

# %%
plt.pie(df["WorldShare"][:10], labels=df.index[:10], rotatelabels=True, labeldistance=0.3)
None
