# %% [markdown]
# ## Gym Spaces

# %% [markdown]
# Weitere Begriffe: Spaces
# - Discrete: X verschiedene Werte
# - Box: Bereich von Werten (X-Y)
# - Sequence: Beliebig viele Werte (effektiv eine Liste)

# %%
import gymnasium as gym
from gymnasium.spaces import Discrete, Box, Sequence
import numpy as np
from typing import Optional

# %%
d = Discrete(3)
for x in range(10):
    print(d.sample())
# Out:
# 2
# 0
# 2
# 1
# 1
# 1
# 0
# 1
# 2
# 2

# %%
b = Box(0, 1)
b.sample()
# Out:
# array([0.27835065], dtype=float32)

# %%
Box(0, 1, shape=(3,)).sample()
# Out:
# array([0.45214197, 0.5838016 , 0.9584438 ], dtype=float32)

# %%
Box(0, 1, shape=(3, 3)).sample()
# Out:
# array([[0.51214504, 0.07954149, 0.2866445 ],
#        [0.66909397, 0.6246519 , 0.43020725],
#        [0.9470782 , 0.4826286 , 0.65197414]], dtype=float32)

# %%
Box(0, 100, shape=(3, 3), dtype=int).sample()
# Out:
# array([[19, 31, 75],
#        [26, 90, 86],
#        [82, 59,  7]])

# %%
Sequence(Box(0, 1)).sample()
# Out:
# (array([0.5819444], dtype=float32),
#  array([0.38592443], dtype=float32),
#  array([0.35165536], dtype=float32),
#  array([0.97796726], dtype=float32),
#  array([0.38957372], dtype=float32),
#  array([0.15212134], dtype=float32),
#  array([0.70136464], dtype=float32))

# %% [markdown]
# ## Eigene Umgebung

# %% [markdown]
# Eine eigene Umgebung muss drei Dinge enthalten:
# - Action Space
#     - Möglichen Aktionen des Agenten
#
# - Observation Space
#     - Daten die für die Beobachtung verwendet werden
#
# - State
#     - Zustand der Umgebung
#
# Unsere Umgebung muss von env erben
#
# ---

# %% [markdown]
# Beispiel: Autofahrer
#
# Geschwindigkeit soll zwischen 45 und 55 km/h gehalten werden

# %%
class CarDriver(gym.Env):
    def __init__(self):
        self.action_space = Discrete(3)  # Drei Aktionen: Bremsen, Beschleunigen, Nichts
        self.observation_space = Box(0, 100, dtype=np.int8)  # Geschwindigkeitsgrenzen
        self.state = 40 + np.random.randint(10)
        self.drive_length = 60

    def step(self, action):
        # Action verwenden
        # 0: +-0km/h
        # 1: -3km/h
        # 2: +3km/h
        if action == 1:
            self.state -= 3
        if action == 2:
            self.state += 3

        if self.state >= 45 and self.state <= 55:
            reward = 1
        else:
            reward = -1

        self.drive_length -= 1
        
        # Hier kommen 5 Rückgabewerte heraus: Den Game State (Observation Space), die Belohnung, Verloren Ja/Nein, Spiel zu Ende (optional), Info: Beliebige Daten
        return np.array(self.state, dtype=np.int8).reshape(1,), reward, self.drive_length <= 0, False, {}

    def reset(self, *, seed: Optional[int] = None, options: Optional[dict] = None):
        self.state = 40 + np.random.randint(10)
        self.drive_length = 60
        return (np.array(self.state, dtype=np.int8).reshape(1, ), {})

# %%
def testEnv(env, durchgaenge):
    for d in range(durchgaenge):
        state = env.reset()
        score = 0
        terminate = False

        # Diese Schleife spielt das Spiel
        while not terminate:
            action = env.action_space.sample()
            state, reward, terminate, done, info = env.step(action)
            score += reward
        print(f"Durchgang {d + 1}: Score {score}")

# %%
env = CarDriver()

# %%
testEnv(env, 10)
# Out:
# Durchgang 1: Score -38
# Durchgang 2: Score -34
# Durchgang 3: Score -32
# Durchgang 4: Score 40
# Durchgang 5: Score -50
# Durchgang 6: Score 0
# Durchgang 7: Score 14
# Durchgang 8: Score -16
# Durchgang 9: Score -12
# Durchgang 10: Score 24

# %% [markdown]
# ## Env Checker

# %%
from stable_baselines3.common.env_checker import check_env

# %%
check_env(env, warn=True)

# %% [markdown]
# ## Modell erstellen

# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
env = CarDriver()
env = DummyVecEnv([lambda: env])
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=200000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1996 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1420        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010081819 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00208     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.6        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 67.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1268       |
# |    iterations           | 3          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01008841 |
# |    clip_fraction        | 0.0538     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | -0.00965   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 28         |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00383   |
# |    value_loss           | 60         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1223        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.004304981 |
# |    clip_fraction        | 0.00947     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000113   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00141    |
# |    value_loss           | 58.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1190         |
# |    iterations           | 5            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0053693037 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.00166     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.5         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00992     |
# |    value_loss           | 74.5         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1106       |
# |    iterations           | 6          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00852006 |
# |    clip_fraction        | 0.0318     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.00221    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 38.3       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00262   |
# |    value_loss           | 63.7       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1083        |
# |    iterations           | 7           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.003778208 |
# |    clip_fraction        | 0.0114      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.00304     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47          |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 81.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1067        |
# |    iterations           | 8           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009024641 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.00731     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.4        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00744    |
# |    value_loss           | 68.9        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1066       |
# |    iterations           | 9          |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00636449 |
# |    clip_fraction        | 0.0587     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | -0.0255    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34.1       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00591   |
# |    value_loss           | 67.7       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1065         |
# |    iterations           | 10           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0056863558 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.0201      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30           |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00441     |
# |    value_loss           | 62.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1060        |
# |    iterations           | 11          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011357285 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.000604    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.3        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 50.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1059        |
# |    iterations           | 12          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010945831 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.000123    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.5        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 40.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1059        |
# |    iterations           | 13          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010971718 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.00101     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.6        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00832    |
# |    value_loss           | 39.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1061         |
# |    iterations           | 14           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0069308537 |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 7e-05        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.8         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00403     |
# |    value_loss           | 46.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1060        |
# |    iterations           | 15          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.014524188 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -8.79e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34          |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00361    |
# |    value_loss           | 59.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1058         |
# |    iterations           | 16           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0073455237 |
# |    clip_fraction        | 0.0872       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -3.16e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.6         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | 0.00117      |
# |    value_loss           | 66           |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1053       |
# |    iterations           | 17         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01381485 |
# |    clip_fraction        | 0.107      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1         |
# |    explained_variance   | -9.42e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 30.9       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.00135    |
# |    value_loss           | 77.5       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1046         |
# |    iterations           | 18           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0041508693 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | -1.41e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.8         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | 0.00448      |
# |    value_loss           | 77.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1033        |
# |    iterations           | 19          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010171531 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.997      |
# |    explained_variance   | 5.01e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28          |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00243    |
# |    value_loss           | 88.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1022        |
# |    iterations           | 20          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007498821 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -2.98e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37          |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.0035      |
# |    value_loss           | 89.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1019        |
# |    iterations           | 21          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.011701181 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | -6.56e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.4        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00316     |
# |    value_loss           | 96.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1013        |
# |    iterations           | 22          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.013305697 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.984      |
# |    explained_variance   | -1.2e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.8        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.000638   |
# |    value_loss           | 93.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1010         |
# |    iterations           | 23           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0101338895 |
# |    clip_fraction        | 0.135        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.987       |
# |    explained_variance   | -8.58e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.7         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.00214      |
# |    value_loss           | 95.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1010         |
# |    iterations           | 24           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0044185994 |
# |    clip_fraction        | 0.181        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.978       |
# |    explained_variance   | -5.36e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.7         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | 0.0064       |
# |    value_loss           | 103          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1009        |
# |    iterations           | 25          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009206463 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.97       |
# |    explained_variance   | -4.41e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.2        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00247     |
# |    value_loss           | 98          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1009        |
# |    iterations           | 26          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.014575041 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.976      |
# |    explained_variance   | -7.99e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.7        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.000986   |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1004        |
# |    iterations           | 27          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008818171 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.971      |
# |    explained_variance   | -7.51e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49          |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.00253     |
# |    value_loss           | 90.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 999         |
# |    iterations           | 28          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012173256 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.955      |
# |    explained_variance   | -3.34e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.7        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00369     |
# |    value_loss           | 84.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 994         |
# |    iterations           | 29          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008091401 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | -2.62e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.2        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00489     |
# |    value_loss           | 88.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 989        |
# |    iterations           | 30         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.00795604 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.958     |
# |    explained_variance   | -2.98e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 44.5       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | 0.00346    |
# |    value_loss           | 99.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 988        |
# |    iterations           | 31         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.01226767 |
# |    clip_fraction        | 0.152      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.952     |
# |    explained_variance   | -1.43e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 49.7       |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.00664    |
# |    value_loss           | 94.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 975         |
# |    iterations           | 32          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010575039 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.955      |
# |    explained_variance   | -1.43e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.3        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00311     |
# |    value_loss           | 97.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 963         |
# |    iterations           | 33          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.004064891 |
# |    clip_fraction        | 0.0975      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.95       |
# |    explained_variance   | -7.15e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58          |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00389     |
# |    value_loss           | 103         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 963         |
# |    iterations           | 34          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006391637 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.941      |
# |    explained_variance   | -1.31e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.4        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00871     |
# |    value_loss           | 98.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 964         |
# |    iterations           | 35          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.017219255 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61          |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00361     |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 965         |
# |    iterations           | 36          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010636341 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.6        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 2.88e-06    |
# |    value_loss           | 104         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 967         |
# |    iterations           | 37          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.009387711 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.5        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0041      |
# |    value_loss           | 107         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 968        |
# |    iterations           | 38         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.01800976 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.923     |
# |    explained_variance   | -2.38e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 46.8       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | 0.00494    |
# |    value_loss           | 108        |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 969          |
# |    iterations           | 39           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0051310724 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.938       |
# |    explained_variance   | -9.54e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.5         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.00387      |
# |    value_loss           | 108          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 969        |
# |    iterations           | 40         |
# |    time_elapsed         | 84         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.01786109 |
# |    clip_fraction        | 0.163      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.932     |
# |    explained_variance   | -8.34e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 46.6       |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.00587    |
# |    value_loss           | 111        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 971         |
# |    iterations           | 41          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.011456088 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.926      |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.9        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00646     |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 42          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006512569 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.919      |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.8        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00805     |
# |    value_loss           | 113         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 973          |
# |    iterations           | 43           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0034180149 |
# |    clip_fraction        | 0.162        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.919       |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72.5         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.00818      |
# |    value_loss           | 114          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 974         |
# |    iterations           | 44          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008904695 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.912      |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.8        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00457     |
# |    value_loss           | 116         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 974         |
# |    iterations           | 45          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008007207 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.8        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00307     |
# |    value_loss           | 115         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 975        |
# |    iterations           | 46         |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.02591183 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.896     |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 41.6       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.00429    |
# |    value_loss           | 117        |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 976          |
# |    iterations           | 47           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0075659403 |
# |    clip_fraction        | 0.153        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.914       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52           |
# |    n_updates            | 460          |
# |    policy_gradient_loss | 0.00546      |
# |    value_loss           | 116          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 977         |
# |    iterations           | 48          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008296762 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.902      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.8        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00632     |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 977         |
# |    iterations           | 49          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.009929245 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.902      |
# |    explained_variance   | 4.77e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.3        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00251     |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 973         |
# |    iterations           | 50          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.010361222 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.893      |
# |    explained_variance   | 6.56e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.5        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00508     |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 973         |
# |    iterations           | 51          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.019305985 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.889      |
# |    explained_variance   | 8.94e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.5        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00764     |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 974         |
# |    iterations           | 52          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.013924965 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | 8.34e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.4        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00515     |
# |    value_loss           | 109         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 975          |
# |    iterations           | 53           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0068380916 |
# |    clip_fraction        | 0.202        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.911       |
# |    explained_variance   | 2.38e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 74.9         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | 0.0109       |
# |    value_loss           | 110          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 54          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.008897087 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 1.91e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.4        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.0038      |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 55          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.028936096 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.889      |
# |    explained_variance   | 6.38e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.8        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.00621     |
# |    value_loss           | 107         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 56          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.012920054 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.891      |
# |    explained_variance   | 1.8e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.4        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | 0.00645     |
# |    value_loss           | 109         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 977         |
# |    iterations           | 57          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.010800183 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.887      |
# |    explained_variance   | 7.09e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.3        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | 0.00554     |
# |    value_loss           | 115         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 977          |
# |    iterations           | 58           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0069492506 |
# |    clip_fraction        | 0.155        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.881       |
# |    explained_variance   | 3.04e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.9         |
# |    n_updates            | 570          |
# |    policy_gradient_loss | 0.00531      |
# |    value_loss           | 115          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 978         |
# |    iterations           | 59          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.008851098 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.89       |
# |    explained_variance   | 3.76e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.2        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | 0.0073      |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 978         |
# |    iterations           | 60          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.008243536 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.889      |
# |    explained_variance   | 0.000193    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.5        |
# |    n_updates            | 590         |
# |    policy_gradient_loss | 0.00793     |
# |    value_loss           | 108         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 978         |
# |    iterations           | 61          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.010425892 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.885      |
# |    explained_variance   | 0.000666    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.8        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00132    |
# |    value_loss           | 109         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 975         |
# |    iterations           | 62          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.006194853 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.878      |
# |    explained_variance   | 0.00123     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58          |
# |    n_updates            | 610         |
# |    policy_gradient_loss | 0.00397     |
# |    value_loss           | 93.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 974         |
# |    iterations           | 63          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.008518511 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.879      |
# |    explained_variance   | 0.000953    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.2        |
# |    n_updates            | 620         |
# |    policy_gradient_loss | 0.00403     |
# |    value_loss           | 89          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 973         |
# |    iterations           | 64          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.011242198 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.886      |
# |    explained_variance   | 0.00178     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.8        |
# |    n_updates            | 630         |
# |    policy_gradient_loss | 0.00362     |
# |    value_loss           | 96.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# ...
# |    policy_gradient_loss | 0.00787     |
# |    value_loss           | 113         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 78          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.009749672 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | 0.00428     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.8        |
# |    n_updates            | 770         |
# |    policy_gradient_loss | 0.00336     |
# |    value_loss           | 113         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 977         |
# |    iterations           | 79          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 161792      |
# | train/                  |             |
# |    approx_kl            | 0.009270045 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.872      |
# |    explained_variance   | 0.00603     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.3        |
# |    n_updates            | 780         |
# |    policy_gradient_loss | 0.00404     |
# |    value_loss           | 113         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 977         |
# |    iterations           | 80          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.007361174 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 0.00541     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.9        |
# |    n_updates            | 790         |
# |    policy_gradient_loss | 0.0045      |
# |    value_loss           | 94.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 977         |
# |    iterations           | 81          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.035421185 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.857      |
# |    explained_variance   | 0.0109      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.1        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | 0.00359     |
# |    value_loss           | 97.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 978          |
# |    iterations           | 82           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0069611026 |
# |    clip_fraction        | 0.143        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.844       |
# |    explained_variance   | 0.012        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43           |
# |    n_updates            | 810          |
# |    policy_gradient_loss | 0.00275      |
# |    value_loss           | 93.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 978         |
# |    iterations           | 83          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.009587886 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.836      |
# |    explained_variance   | 0.0196      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.4        |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.000553   |
# |    value_loss           | 85.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 978          |
# |    iterations           | 84           |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0067528924 |
# |    clip_fraction        | 0.163        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.827       |
# |    explained_variance   | 0.0173       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45           |
# |    n_updates            | 830          |
# |    policy_gradient_loss | 0.00415      |
# |    value_loss           | 82.1         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 979        |
# |    iterations           | 85         |
# |    time_elapsed         | 177        |
# |    total_timesteps      | 174080     |
# | train/                  |            |
# |    approx_kl            | 0.01246345 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.812     |
# |    explained_variance   | 0.0193     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.2       |
# |    n_updates            | 840        |
# |    policy_gradient_loss | -0.000286  |
# |    value_loss           | 77.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 979         |
# |    iterations           | 86          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.008554348 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.811      |
# |    explained_variance   | 0.0169      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.1        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | 0.00825     |
# |    value_loss           | 72.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 979         |
# |    iterations           | 87          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.006482362 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.792      |
# |    explained_variance   | 0.0231      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.1        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | 0.00855     |
# |    value_loss           | 76.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 980         |
# |    iterations           | 88          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.010656951 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.793      |
# |    explained_variance   | 0.0289      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.2        |
# |    n_updates            | 870         |
# |    policy_gradient_loss | 0.00457     |
# |    value_loss           | 76          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 980          |
# |    iterations           | 89           |
# |    time_elapsed         | 185          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0122200735 |
# |    clip_fraction        | 0.191        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.775       |
# |    explained_variance   | 0.0173       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.6         |
# |    n_updates            | 880          |
# |    policy_gradient_loss | 0.00984      |
# |    value_loss           | 84.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 979         |
# |    iterations           | 90          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.009171381 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.734      |
# |    explained_variance   | 0.0125      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.3        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | 0.00584     |
# |    value_loss           | 91.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 91          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.011742119 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.705      |
# |    explained_variance   | 0.0173      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.7        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | 0.00572     |
# |    value_loss           | 99.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 92          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.009544203 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.655      |
# |    explained_variance   | 0.0104      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.2        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | 0.0172      |
# |    value_loss           | 98.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 970         |
# |    iterations           | 93          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.034649502 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.644      |
# |    explained_variance   | 0.0248      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75.6        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | 0.00278     |
# |    value_loss           | 113         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 969         |
# |    iterations           | 94          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.057541884 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.632      |
# |    explained_variance   | 0.0237      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.3        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | 0.00726     |
# |    value_loss           | 107         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 969        |
# |    iterations           | 95         |
# |    time_elapsed         | 200        |
# |    total_timesteps      | 194560     |
# | train/                  |            |
# |    approx_kl            | 0.07764523 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.642     |
# |    explained_variance   | 0.0318     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 48.5       |
# |    n_updates            | 940        |
# |    policy_gradient_loss | 0.0117     |
# |    value_loss           | 111        |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 970       |
# |    iterations           | 96        |
# |    time_elapsed         | 202       |
# |    total_timesteps      | 196608    |
# | train/                  |           |
# |    approx_kl            | 0.0363977 |
# |    clip_fraction        | 0.26      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.632    |
# |    explained_variance   | 0.0222    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 35.4      |
# |    n_updates            | 950       |
# |    policy_gradient_loss | 0.0325    |
# |    value_loss           | 111       |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 970         |
# |    iterations           | 97          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.011403334 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.0168      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45          |
# |    n_updates            | 960         |
# |    policy_gradient_loss | 0.0257      |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 970         |
# |    iterations           | 98          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.003847687 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.578      |
# |    explained_variance   | 0.0238      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.6        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | 0.011       |
# |    value_loss           | 120         |
# -----------------------------------------

# %%
model.save("Models/CarDriver")

# %%
env = CarDriver()

# %%
model = PPO.load("Models/CarDriver.zip", env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
def testEnvPredict(env, durchgaenge):
    for d in range(durchgaenge):
        state = env.reset() # Am Anfang des Durchgangs die Umgebung zurücksetzen
        score = 0
        terminate = False
        done = False

        while not (terminate or done):
            if len(state) == 2:
                action = model.predict(np.array(state[0]))
            else:
                action = model.predict(np.array(state))
            state, reward, terminate, done, info = env.step(action[0])  # Führe einen Step mit der Random Action aus
            # Hier kommen 5 Rückgabewerte heraus: Den Game State (Observation Space), die Belohnung, Verloren Ja/Nein, Spiel zu Ende (optional), Info: Beliebige Daten
            score += reward
        print(f"Durchgang {d + 1}: Score {score}")
    env.close()

# %%
testEnvPredict(env, 10)
# Out:
# Durchgang 1: Score 58
# Durchgang 2: Score 44
# Durchgang 3: Score 60
# Durchgang 4: Score 58
# Durchgang 5: Score 58
# Durchgang 6: Score 56
# Durchgang 7: Score 36
# Durchgang 8: Score 60
# Durchgang 9: Score 60
# Durchgang 10: Score 60
